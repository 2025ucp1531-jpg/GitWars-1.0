# %% [markdown]
# <a href="https://colab.research.google.com/github/2025ucp1531-jpg/GitWars-1.0/blob/main/pythonproject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("enter the number of tasks: "))
list=[]
for i in range(n):
  task=input(f"enter task{i+1}: ")
  list.append(task)

completed_tasks=[]
incomplete_tasks=[]

print("\n review your tasks:")

for task in list:
  status=input(f"did you complete {task}? (yes/no): ").lower()
  if status=="yes":
    completed_tasks.append(task)
  else:
    incomplete_tasks.append(task)

print("\n completed tasks: ")
for task in completed_tasks:
  print("-",task)

print("\n incomplete tasks: ")
for task in incomplete_tasks:
  print("-",task)
# Out:
# enter the number of tasks: 4
# enter task1: dsa
# enter task2: python
# enter task3: mern
# enter task4: ml
#
#  review your tasks:
# did you complete dsa? (yes/no): yEs
# did you complete python? (yes/no): no
# did you complete mern? (yes/no): yes
# did you complete ml? (yes/no): yes
#
#  completed tasks:
# - dsa
# - mern
# - ml
#
#  incomplete tasks:
# - python
